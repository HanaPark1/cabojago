# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.15.2)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from selenium) (1.26.7)
# Requirement already satisfied: trio~=0.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from selenium) (0.23.1)
# Requirement already satisfied: trio-websocket~=0.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: attrs>=20.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: sortedcontainers in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip3 install webdriver_manager
# Out:
# Requirement already satisfied: webdriver_manager in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (4.0.1)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from webdriver_manager) (2.26.0)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from webdriver_manager) (1.0.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from webdriver_manager) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from packaging->webdriver_manager) (3.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->webdriver_manager) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->webdriver_manager) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->webdriver_manager) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->webdriver_manager) (3.3)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
# selenium: 웹 브라우저를 이용, 웹 사이트 제어를 위해 사용
# bs4: html에서 데이터 추출, html 및 xml 문서를 parsing 하기 위해 사용

# %% [markdown]
# ### 네이버 지도 카페 상세 정보

# %%
from time import sleep
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

import os
import pandas as pd
import re

# %%
os.getcwd()# CSV 파일 경로 리스트
csv_file_paths = [
    # '../data/cafelist_망원동.csv',
    # '../data/cafelist_성수동.csv',
    # '../data/cafelist_연남동.csv',
    # '../data/cafelist/cafelist_한남동.csv',
    '../data/cafelist/cafelist_망원동.csv',
    '../data/cafelist/cafelist_연희동.csv',
]

sleep(3)

# %%
# 결과를 저장할 리스트
data_list = []

# %%
# 필요한 예외를 import
from selenium.common.exceptions import TimeoutException
for csv_file_path in csv_file_paths:
    data_list = []
    # CSV 파일 읽기
    df_names = pd.read_csv(csv_file_path)

    # 네이버 지도에서 크롤링
    chrome_options = webdriver.ChromeOptions()
    chrome_options.add_argument("/Users/yangchaeyeon/Downloads/chromedriver-mac-arm64")
    driver = webdriver.Chrome(options=chrome_options)
    driver.get("https://map.naver.com/p")

    for _, row in df_names.iterrows():
        key_word = row['name']
        print(key_word)
        
        # 네이버 지도 페이지 로딩
        driver.get("https://map.naver.com/p")

        # 검색창에 카페 이름 입력
        search = WebDriverWait(driver, 5).until(
            EC.presence_of_element_located((By.CSS_SELECTOR, 'div.input_box > input.input_search')))
        search.clear()
        search.send_keys(key_word)
        search.send_keys(Keys.ENTER)
        
        # 해당 카페에 바로 가는지, 여러 카페 목록에서 클릭해서 들어가야하는지 예외 처리 
        iframe_present = False
        try:
            iframe = WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CSS_SELECTOR, "iframe#entryIframe")))
            driver.switch_to.frame(iframe)
            iframe_present = True
        except TimeoutException as e:
            pass
        
        if not iframe_present:
            
            try:
                iframe = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, '//*[@id="searchIframe"]')))
                driver.switch_to.frame(iframe)
                element = WebDriverWait(driver, 5).until(
                    EC.presence_of_element_located((By.XPATH, '//*[@id="_pcmap_list_scroll_container"]/ul/li[1]/div[1]/div[2]/a[1]/div/div')))
                # 원하는 요소가 있는 경우에만 처리
                element.click()
                driver.switch_to.default_content()
                iframe = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, '//*[@id="entryIframe"]')))
                driver.switch_to.frame(iframe)
            except TimeoutException as e:
                # 원하는 요소를 찾지 못한 경우 다음 카페로 넘어가기
                print("해당 카페에 대한 정보를 수집할 수 없습니다.")
                continue

        # 카페 고유 ID
        try:
            ID_element = WebDriverWait(driver, 3).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, 'span.PXMot > a')))
            href = ID_element.get_attribute('href')
            cafe_ID = re.search(r'\d+', href).group()
            print("카페 고유 ID", cafe_ID)
        except Exception as e:
            cafe_ID = 'N/A'
        
    
        # 카페 방문자 수      
        try:
            cafe_visit = WebDriverWait(driver, 2).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, 'span.PXMot > a'))).text
            visit_count = re.sub(r'\D', '', cafe_visit)
        except Exception as e:
            cafe_visit = 'N/A'
            
        # 카페 블로그리뷰수
        try:
            cafe_blog = WebDriverWait(driver, 3).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, 'span.PXMot:last-child > a'))).text
            blog_count = re.sub(r'\D', '', cafe_blog)
        except Exception as e:
            cafe_blog = 'N/A'
        
        # 카페 주소
        try:
            address = WebDriverWait(driver, 2).until(
                EC.presence_of_element_located((By.CSS_SELECTOR, 'a.PkgBl > span.LDgIH'))).text
        except Exception as e:
            address = 'N/A'

        data_list.append({
            '카페ID': cafe_ID,
            '카페이름': key_word,
            '방문자리뷰': visit_count,
            '블로그리뷰': blog_count,
            '주소': address
        })
        print(data_list[-1])
        
        sleep(7)

    # 크롬 드라이버 종료
    driver.quit()
    
    # DataFrame 생성
    df_cafe_info = pd.DataFrame(data_list)

    # 결과를 CSV로 저장
    csv_output_path = f'output_{os.path.basename(csv_file_path)}'
    df_cafe_info.to_csv(csv_output_path, index=False)
# Out:
# 와아
# 카페 고유 ID 1299421546
# {'카페ID': '1299421546', '카페이름': '와아', '방문자리뷰': '340', '블로그리뷰': '18', '주소': '서울 성동구 상원2길 1-10 3층'}
# 침묵을깨다
# 카페 고유 ID 1053160252
# {'카페ID': '1053160252', '카페이름': '침묵을깨다', '방문자리뷰': '188', '블로그리뷰': '205', '주소': '서울 성동구 아차산로11길 26 2층'}
# 차일디쉬
# 카페 고유 ID 1217287130
# {'카페ID': '1217287130', '카페이름': '차일디쉬', '방문자리뷰': '276', '블로그리뷰': '343', '주소': '서울 성동구 연무장길 114 2층 차일디쉬'}
# 자연도소금빵in 성수
# 카페 고유 ID 1022429915
# {'카페ID': '1022429915', '카페이름': '자연도소금빵in 성수', '방문자리뷰': '799', '블로그리뷰': '829', '주소': '서울 성동구 연무장길 56-1 1층'}
# 한정선
# 카페 고유 ID 1353954221
# {'카페ID': '1353954221', '카페이름': '한정선', '방문자리뷰': '143', '블로그리뷰': '148', '주소': '서울 성동구 연무장길 54-1 1층'}
# 치즈인더스트리 성수
# 카페 고유 ID 1407454916
# {'카페ID': '1407454916', '카페이름': '치즈인더스트리 성수', '방문자리뷰': '157', '블로그리뷰': '143', '주소': '서울 성동구 성수이로18길 37 1층'}
# 츄로101 성수점
# 카페 고유 ID 1339900302
# {'카페ID': '1339900302', '카페이름': '츄로101 성수점', '방문자리뷰': '75', '블로그리뷰': '83', '주소': '서울 성동구 성덕정길 70 1층'}
# 모리노키세츠
# 카페 고유 ID 1724311124
# {'카페ID': '1724311124', '카페이름': '모리노키세츠', '방문자리뷰': '55', '블로그리뷰': '47', '주소': '서울 성동구 서울숲2길 11-16 2층'}
# 하이라인
# 카페 고유 ID 1194510469
# {'카페ID': '1194510469', '카페이름': '하이라인', '방문자리뷰': '528', '블로그리뷰': '4874', '주소': '서울 성동구 성덕정9길 10 2층 오른쪽문'}
# 오우드 성수1호점
# 카페 고유 ID 1833313793
# {'카페ID': '1833313793', '카페이름': '오우드 성수1호점', '방문자리뷰': '1534', '블로그리뷰': '4874', '주소': '서울 성동구 연무장길 101-1'}
# 베통 성수
# 카페 고유 ID 365858525
# {'카페ID': '365858525', '카페이름': '베통 성수', '방문자리뷰': '3566', '블로그리뷰': '4874', '주소': '서울 성동구 연무장7가길 8'}
# 파머스카페
# 카페 고유 ID 1703770592
# {'카페ID': '1703770592', '카페이름': '파머스카페', '방문자리뷰': '53', '블로그리뷰': '19', '주소': '경남 진주시 진주대로542번길 9-1 1층'}
# 브레디포스트 성수
# 카페 고유 ID 1020816080
# {'카페ID': '1020816080', '카페이름': '브레디포스트 성수', '방문자리뷰': '2048', '블로그리뷰': '2306', '주소': '서울 성동구 상원1길 5 1층'}
# 웜브라운
# 카페 고유 ID 1734893193
# {'카페ID': '1734893193', '카페이름': '웜브라운', '방문자리뷰': '121', '블로그리뷰': '104', '주소': '서울 성동구 연무장길 16-2 1층 WARM BRAUN'}
# 니커버커베이글 성수지점
# 카페 고유 ID 1468687611
# {'카페ID': '1468687611', '카페이름': '니커버커베이글 성수지점', '방문자리뷰': '82', '블로그리뷰': '140', '주소': '서울 성동구 뚝섬로13길 36 1층~3층'}
# 본지르르 성수
# 카페 고유 ID 1771016332
# {'카페ID': '1771016332', '카페이름': '본지르르 성수', '방문자리뷰': '19', '블로그리뷰': '75', '주소': '서울 성동구 광나루로4가길 13 B1, 1, 2층'}
# 마를리
# 카페 고유 ID 742676592
# {'카페ID': '742676592', '카페이름': '마를리', '방문자리뷰': '3454', '블로그리뷰': '1943', '주소': '서울 성동구 연무장길 47 홍원빌딩'}
# 아쿠아산타 성수카페
# 카페 고유 ID 1517487358
# {'카페ID': '1517487358', '카페이름': '아쿠아산타 성수카페', '방문자리뷰': '1280', '블로그리뷰': '575', '주소': '서울 성동구 연무장길 81 1층 107호'}
# 서울앵무새
# 카페 고유 ID 1240372795
# {'카페ID': '1240372795', '카페이름': '서울앵무새', '방문자리뷰': '5020', '블로그리뷰': '575', '주소': '서울 성동구 서울숲9길 3 B1~2F'}
# 크림라벨 서울숲 본점
# 카페 고유 ID 1455299135
# {'카페ID': '1455299135', '카페이름': '크림라벨 서울숲 본점', '방문자리뷰': '1105', '블로그리뷰': '328', '주소': '서울 성동구 서울숲2길 34 1층'}
# 쎈느Scene
# 카페 고유 ID 1030871168
# {'카페ID': '1030871168', '카페이름': '쎈느Scene', '방문자리뷰': '1984', '블로그리뷰': '328', '주소': '서울 성동구 연무장5길 20 1F Scène'}
# 카페 할아버지공장
# 카페 고유 ID 1425989301
# {'카페ID': '1425989301', '카페이름': '카페 할아버지공장', '방문자리뷰': '4978', '블로그리뷰': '2259', '주소': '서울 성동구 성수이로7가길 9'}
# 스트로베리32 성수점
# 카페 고유 ID 1128626529
# {'카페ID': '1128626529', '카페이름': '스트로베리32 성수점', '방문자리뷰': '2104', '블로그리뷰': '410', '주소': '서울 성동구 왕십리로10길 9-31 3층'}
# 퍼먼트
# 카페 고유 ID 1694234920
# {'카페ID': '1694234920', '카페이름': '퍼먼트', '방문자리뷰': '1251', '블로그리뷰': '842', '주소': '서울 성동구 서울숲2길 37 1층 , 지하'}
# 성수 베이킹 스튜디오
# 카페 고유 ID 1523663774
# {'카페ID': '1523663774', '카페이름': '성수 베이킹 스튜디오', '방문자리뷰': '2613', '블로그리뷰': '842', '주소': '서울 성동구 서울숲2길 46 B1층'}
# 어니언 성수
# 카페 고유 ID 38561949
# {'카페ID': '38561949', '카페이름': '어니언 성수', '방문자리뷰': '4399', '블로그리뷰': '842', '주소': '서울 성동구 아차산로9길 8 어니언'}
# 밀도 성수점
# 카페 고유 ID 37717085
# {'카페ID': '37717085', '카페이름': '밀도 성수점', '방문자리뷰': '6472', '블로그리뷰': '842', '주소': '서울 성동구 왕십리로 96'}
# LOOOP 루프 베이커리 카페
# 카페 고유 ID 1935471901
# {'카페ID': '1935471901', '카페이름': 'LOOOP 루프 베이커리 카페', '방문자리뷰': '1251', '블로그리뷰': '842', '주소': '서울 성동구 연무장5길 9-13 1층'}
# 피넛버터바나나
# 카페 고유 ID 1136906451
# {'카페ID': '1136906451', '카페이름': '피넛버터바나나', '방문자리뷰': '1368', '블로그리뷰': '304', '주소': '서울 성동구 아차산로7길 15-8 1층,2층'}
# 비아트 성수
# 카페 고유 ID 1251057335
# {'카페ID': '1251057335', '카페이름': '비아트 성수', '방문자리뷰': '467', '블로그리뷰': '425', '주소': '서울 성동구 아차산로5길 24-45 2층'}
# 체다앤올리
# 카페 고유 ID 343496704
# {'카페ID': '343496704', '카페이름': '체다앤올리', '방문자리뷰': '1455', '블로그리뷰': '425', '주소': '서울 성동구 서울숲2길 32-14 갤러리아포레 상가 102동 113호'}
# 실버리
# 카페 고유 ID 1394826865
# {'카페ID': '1394826865', '카페이름': '실버리', '방문자리뷰': '142', '블로그리뷰': '24', '주소': '서울 성동구 서울숲4길 26 2층'}
# 묘사서울
# 카페 고유 ID 1409603517
# {'카페ID': '1409603517', '카페이름': '묘사서울', '방문자리뷰': '593', '블로그리뷰': '24', '주소': '서울 성동구 서울숲2길 2 2층'}
# 라프레플루트
# 카페 고유 ID 1966521856
# {'카페ID': '1966521856', '카페이름': '라프레플루트', '방문자리뷰': '656', '블로그리뷰': '543', '주소': '서울 성동구 서울숲2길 8-8 2층'}
# 누데이크 성수
# 카페 고유 ID 1691420621
# {'카페ID': '1691420621', '카페이름': '누데이크 성수', '방문자리뷰': '1594', '블로그리뷰': '1069', '주소': '서울 성동구 성수이로7길 26 1층'}
# LOWIDE 서울숲
# 카페 고유 ID 1687687205
# {'카페ID': '1687687205', '카페이름': 'LOWIDE 서울숲', '방문자리뷰': '3122', '블로그리뷰': '1543', '주소': '서울 성동구 서울숲2길 22-1'}
# 맥파이앤타이거 성수티룸
# 카페 고유 ID 1038370038
# {'카페ID': '1038370038', '카페이름': '맥파이앤타이거 성수티룸', '방문자리뷰': '272', '블로그리뷰': '309', '주소': '서울 성동구 성수이로 97 5층'}
# 브라우터
# 카페 고유 ID 1723681649
# {'카페ID': '1723681649', '카페이름': '브라우터', '방문자리뷰': '167', '블로그리뷰': '309', '주소': '서울 성동구 왕십리로14길 28-21 지상 1~4층'}
# 코끼리베이글 성수
# 카페 고유 ID 1543901744
# {'카페ID': '1543901744', '카페이름': '코끼리베이글 성수', '방문자리뷰': '3031', '블로그리뷰': '1633', '주소': '서울 성동구 성수이로26길 17 (성수동2가) 1층'}
# 러프러프
# 카페 고유 ID 1829908685
# {'카페ID': '1829908685', '카페이름': '러프러프', '방문자리뷰': '700', '블로그리뷰': '845', '주소': '서울 성동구 연무장길 81 401호'}
# 레인리포트 크루아상
# 카페 고유 ID 1343777269
# {'카페ID': '1343777269', '카페이름': '레인리포트 크루아상', '방문자리뷰': '456', '블로그리뷰': '586', '주소': '서울 성동구 성수이로16길 32 주3 1, 2층'}
# 뵈르뵈르
# 카페 고유 ID 1423662826
# {'카페ID': '1423662826', '카페이름': '뵈르뵈르', '방문자리뷰': '115', '블로그리뷰': '460', '주소': '서울 성동구 연무장7길 8'}
# 구욱희씨 서울숲 본점
# 카페 고유 ID 1712521730
# {'카페ID': '1712521730', '카페이름': '구욱희씨 서울숲 본점', '방문자리뷰': '1731', '블로그리뷰': '460', '주소': '서울 성동구 서울숲4길 12-22 1, 2층'}
# 블루보틀 성수 카페
# 카페 고유 ID 1725895520
# {'카페ID': '1725895520', '카페이름': '블루보틀 성수 카페', '방문자리뷰': '17626', '블로그리뷰': '3876', '주소': '서울 성동구 아차산로 7 케이티링커스'}
# 커피냅로스터스 성수
# 카페 고유 ID 1355804064
# {'카페ID': '1355804064', '카페이름': '커피냅로스터스 성수', '방문자리뷰': '18', '블로그리뷰': '21', '주소': '서울 성동구 성수일로4길 35-11 커피냅로스터스 성수'}
# 봉땅 서울숲점
# 카페 고유 ID 1700801654
# {'카페ID': '1700801654', '카페이름': '봉땅 서울숲점', '방문자리뷰': '343', '블로그리뷰': '337', '주소': '서울 성동구 서울숲6길 16-1 1층 봉땅'}
# 5to7
# 카페 고유 ID 1508243090
# {'카페ID': '1508243090', '카페이름': '5to7', '방문자리뷰': '1571', '블로그리뷰': '337', '주소': '서울 성동구 서울숲2길 44-13 1층'}
# 플디 성수점
# 카페 고유 ID 1030413970
# {'카페ID': '1030413970', '카페이름': '플디 성수점', '방문자리뷰': '833', '블로그리뷰': '337', '주소': '서울 성동구 상원길 44 2층'}
# 꼬모윤 서울숲점
# 카페 고유 ID 1962021779
# {'카페ID': '1962021779', '카페이름': '꼬모윤 서울숲점', '방문자리뷰': '180', '블로그리뷰': '126', '주소': '서울 성동구 서울숲길 50 1층'}
# 텅 성수 스페이스
# 카페 고유 ID 1092567422
# {'카페ID': '1092567422', '카페이름': '텅 성수 스페이스', '방문자리뷰': '2080', '블로그리뷰': '126', '주소': '서울 성동구 성수이로 82 2층'}
# 뉴앳던 성수
# 카페 고유 ID 1789793457
# {'카페ID': '1789793457', '카페이름': '뉴앳던 성수', '방문자리뷰': '751', '블로그리뷰': '393', '주소': '서울 성동구 왕십리로5길 9-20 4층'}
# 에이투비 Cafe&Bar
# 카페 고유 ID 1537971823
# {'카페ID': '1537971823', '카페이름': '에이투비 Cafe&Bar', '방문자리뷰': '833', '블로그리뷰': '393', '주소': '서울 성동구 아차산로 135 2층'}
# 발렁스
# 카페 고유 ID 1988832741
# {'카페ID': '1988832741', '카페이름': '발렁스', '방문자리뷰': '510', '블로그리뷰': '393', '주소': '서울 성동구 성수일로4길 49 1층 발렁스'}
# 치카성수
# 카페 고유 ID 37191703
# {'카페ID': '37191703', '카페이름': '치카성수', '방문자리뷰': '521', '블로그리뷰': '736', '주소': '서울 성동구 뚝섬로1가길 14 1층'}
# 디플랫 성수
# 카페 고유 ID 1886226302
# {'카페ID': '1886226302', '카페이름': '디플랫 성수', '방문자리뷰': '348', '블로그리뷰': '605', '주소': '서울 성동구 연무장길 90 1층'}
# 목로정원
# 카페 고유 ID 1155970418
# {'카페ID': '1155970418', '카페이름': '목로정원', '방문자리뷰': '288', '블로그리뷰': '605', '주소': '서울 성동구 서울숲2길 47 3층'}
# 테디스오븐
# 카페 고유 ID 1239997161
# {'카페ID': '1239997161', '카페이름': '테디스오븐', '방문자리뷰': '1239', '블로그리뷰': '1917', '주소': '서울 성동구 서울숲2길 43 (성수동1 가) 1층'}
# 프롤라
# 카페 고유 ID 1399503871
# {'카페ID': '1399503871', '카페이름': '프롤라', '방문자리뷰': '580', '블로그리뷰': '1212', '주소': '서울 성동구 연무장17길 5 1층'}
# 페로몬
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 마일스톤 커피 성수점
# 카페 고유 ID 1698816534
# {'카페ID': '1698816534', '카페이름': '마일스톤 커피 성수점', '방문자리뷰': '224', '블로그리뷰': '276', '주소': '서울 성동구 서울숲4길 15 1층'}
# 얼스케이크베이크샵
# 카페 고유 ID 1873977601
# {'카페ID': '1873977601', '카페이름': '얼스케이크베이크샵', '방문자리뷰': '202', '블로그리뷰': '385', '주소': '서울 성동구 상원6나길 7 1층'}
# 투데이즈 위켄드
# 카페 고유 ID 1839018422
# {'카페ID': '1839018422', '카페이름': '투데이즈 위켄드', '방문자리뷰': '85', '블로그리뷰': '129', '주소': '서울 성동구 왕십리로5길 14-1 1층'}
# 테니
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 씨장
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 오우드 성수2호점
# 카페 고유 ID 1216172292
# {'카페ID': '1216172292', '카페이름': '오우드 성수2호점', '방문자리뷰': '394', '블로그리뷰': '311', '주소': '서울 성동구 성수이로24길 36 2층'}
# 옹근달
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 타임애프터타임
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 하프커피 성수
# 카페 고유 ID 1321337563
# {'카페ID': '1321337563', '카페이름': '하프커피 성수', '방문자리뷰': '1928', '블로그리뷰': '311', '주소': '서울 성동구 서울숲4길 12 지하1층'}
# 센터커피 서울숲점
# 카페 고유 ID 523890342
# {'카페ID': '523890342', '카페이름': '센터커피 서울숲점', '방문자리뷰': '2395', '블로그리뷰': '311', '주소': '서울 성동구 서울숲2길 28-11'}
# 카멜커피 성수점
# 카페 고유 ID 55585656
# {'카페ID': '55585656', '카페이름': '카멜커피 성수점', '방문자리뷰': '1304', '블로그리뷰': '311', '주소': '서울 성동구 성덕정19길 6 1층'}
# 어라운드데이
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 스타벅스 성수점
# 카페 고유 ID 1679703260
# {'카페ID': '1679703260', '카페이름': '스타벅스 성수점', '방문자리뷰': '2363', '블로그리뷰': '81', '주소': '서울 성동구 아차산로 104'}
# 오우도
# 카페 고유 ID 319626943
# {'카페ID': '319626943', '카페이름': '오우도', '방문자리뷰': '959', '블로그리뷰': '81', '주소': '서울 성동구 성수일로 55 106호'}
# 에르제 성수
# 카페 고유 ID 1734273361
# {'카페ID': '1734273361', '카페이름': '에르제 성수', '방문자리뷰': '2354', '블로그리뷰': '1096', '주소': '서울 성동구 아차산로 135 1층'}
# 까치화방 성수낙낙점
# 카페 고유 ID 1115306852
# {'카페ID': '1115306852', '카페이름': '까치화방 성수낙낙점', '방문자리뷰': '999', '블로그리뷰': '1096', '주소': '서울 성동구 아차산로17길 48 1층 R114호, 115호'}
# 오로라베이커리카페 성수점
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 업사이드커피
# 카페 고유 ID 1259420360
# {'카페ID': '1259420360', '카페이름': '업사이드커피', '방문자리뷰': '763', '블로그리뷰': '1096', '주소': '서울 성동구 연무장13길 3'}
# 브루잉 세레모니
# 카페 고유 ID 1613470297
# {'카페ID': '1613470297', '카페이름': '브루잉 세레모니', '방문자리뷰': '405', '블로그리뷰': '1096', '주소': '서울 성동구 연무장5가길 22-1 1층'}
# 바이닐 성수
# 카페 고유 ID 1656010116
# {'카페ID': '1656010116', '카페이름': '바이닐 성수', '방문자리뷰': '75', '블로그리뷰': '308', '주소': '서울 성동구 아차산로 15-8 2층'}
# 뺑드에코
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 퍼프아웃
# 카페 고유 ID 1925823702
# {'카페ID': '1925823702', '카페이름': '퍼프아웃', '방문자리뷰': '297', '블로그리뷰': '163', '주소': '서울 성동구 연무장길 84 1층'}
# 소프트바
# 카페 고유 ID 1397949769
# {'카페ID': '1397949769', '카페이름': '소프트바', '방문자리뷰': '315', '블로그리뷰': '367', '주소': '서울 성동구 연무장길 54 1층'}
# 더반 베를린 성수점
# 카페 고유 ID 1289885337
# {'카페ID': '1289885337', '카페이름': '더반 베를린 성수점', '방문자리뷰': '543', '블로그리뷰': '416', '주소': '서울 성동구 뚝섬로17길 31-22 더반 베를린 코리아 성수'}
# 바이러닉 에스프레소바
# 카페 고유 ID 1345861465
# {'카페ID': '1345861465', '카페이름': '바이러닉 에스프레소바', '방문자리뷰': '154', '블로그리뷰': '87', '주소': '서울 성동구 상원길 26 1층'}
# 아우프글렛 성수
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 무브모브 성수
# 카페 고유 ID 1859537881
# {'카페ID': '1859537881', '카페이름': '무브모브 성수', '방문자리뷰': '901', '블로그리뷰': '87', '주소': '서울 성동구 성수일로 56'}
# 레이더
# 카페 고유 ID 1525007973
# {'카페ID': '1525007973', '카페이름': '레이더', '방문자리뷰': '1046', '블로그리뷰': '659', '주소': '서울 성동구 연무장길 39-29 레이더'}
# 포지티브 서울숲
# 카페 고유 ID 1069345246
# {'카페ID': '1069345246', '카페이름': '포지티브 서울숲', '방문자리뷰': '338', '블로그리뷰': '232', '주소': '서울 성동구 서울숲2길 45 1층 포지티브'}
# 성수동대림창고갤러리
# 카페 고유 ID 37910590
# {'카페ID': '37910590', '카페이름': '성수동대림창고갤러리', '방문자리뷰': '2740', '블로그리뷰': '232', '주소': '서울 성동구 성수이로 78'}
# 단일서울
# 카페 고유 ID 1346166736
# {'카페ID': '1346166736', '카페이름': '단일서울', '방문자리뷰': '602', '블로그리뷰': '232', '주소': '서울 성동구 왕십리로 66-33 1층'}
# 베티버 성수
# 카페 고유 ID 1383256753
# {'카페ID': '1383256753', '카페이름': '베티버 성수', '방문자리뷰': '827', '블로그리뷰': '574', '주소': '서울 성동구 성덕정11길 18 1층'}
# 삼옥
# 카페 고유 ID 1297713401
# {'카페ID': '1297713401', '카페이름': '삼옥', '방문자리뷰': '278', '블로그리뷰': '253', '주소': '서울 성동구 아차산로7길 17-1 3층'}
# 감도 성수점
# 카페 고유 ID 1424054328
# {'카페ID': '1424054328', '카페이름': '감도 성수점', '방문자리뷰': '844', '블로그리뷰': '344', '주소': '서울 성동구 왕십리로 83-21 디타워 서울포레스트 지하1층 B115 감도'}
# 플럼프
# 카페 고유 ID 1196593317
# {'카페ID': '1196593317', '카페이름': '플럼프', '방문자리뷰': '139', '블로그리뷰': '98', '주소': '서울 성동구 아차산로 83 1층'}
# 천상가옥
# 카페 고유 ID 1071830988
# {'카페ID': '1071830988', '카페이름': '천상가옥', '방문자리뷰': '1890', '블로그리뷰': '939', '주소': '서울 성동구 성수이로14길 14 A동 3층'}
# 코에오 COEO
# 카페 고유 ID 1074798383
# {'카페ID': '1074798383', '카페이름': '코에오 COEO', '방문자리뷰': '110', '블로그리뷰': '125', '주소': '서울 성동구 성수이로16길 45 . 1층'}
# 유스트레스
# 카페 고유 ID 1999678821
# {'카페ID': '1999678821', '카페이름': '유스트레스', '방문자리뷰': '389', '블로그리뷰': '269', '주소': '서울 성동구 연무장7가길 9'}
# 포어플랜
# 카페 고유 ID 1193971273
# {'카페ID': '1193971273', '카페이름': '포어플랜', '방문자리뷰': '430', '블로그리뷰': '469', '주소': '서울 성동구 왕십리로14길 30-11 1층'}
# 슈퍼말차 성수
# 카페 고유 ID 1643583812
# {'카페ID': '1643583812', '카페이름': '슈퍼말차 성수', '방문자리뷰': '1773', '블로그리뷰': '469', '주소': '서울 성동구 서울숲6길 19'}
# 그린랩
# 카페 고유 ID 1295000655
# {'카페ID': '1295000655', '카페이름': '그린랩', '방문자리뷰': '509', '블로그리뷰': '469', '주소': '서울 성동구 서울숲2길 18-11'}
# 오푸
# 카페 고유 ID 1127892000
# {'카페ID': '1127892000', '카페이름': '오푸', '방문자리뷰': '48', '블로그리뷰': '120', '주소': '서울 성동구 뚝섬로 408-7 3층'}
# 로우커피스탠드
# 카페 고유 ID 1168698330
# {'카페ID': '1168698330', '카페이름': '로우커피스탠드', '방문자리뷰': '1176', '블로그리뷰': '651', '주소': '서울 성동구 왕십리로4길 28-2 1층'}
# Y704
# 카페 고유 ID 1386832099
# {'카페ID': '1386832099', '카페이름': 'Y704', '방문자리뷰': '23', '블로그리뷰': '48', '주소': '서울 성동구 연무장길 39-15 2층 Y704'}
# 카페&펍 연무장
# 카페 고유 ID 1247415883
# {'카페ID': '1247415883', '카페이름': '카페&펍 연무장', '방문자리뷰': '852', '블로그리뷰': '1065', '주소': '서울 성동구 연무장길 36 연무장 8층, 카페&펍 연무장'}
# 쿠키샾
# 카페 고유 ID 1624336026
# {'카페ID': '1624336026', '카페이름': '쿠키샾', '방문자리뷰': '434', '블로그리뷰': '254', '주소': '서울 성동구 아차산로 84 1층'}
# 클레멘타인
# 카페 고유 ID 1900288880
# {'카페ID': '1900288880', '카페이름': '클레멘타인', '방문자리뷰': '182', '블로그리뷰': '523', '주소': '서울 성동구 서울숲2길 5-1 1층'}
# 사이드템포
# 카페 고유 ID 1961050470
# {'카페ID': '1961050470', '카페이름': '사이드템포', '방문자리뷰': '311', '블로그리뷰': '141', '주소': '서울 성동구 성덕정길 67 사이드템포'}
# 파티세리후르츠
# 카페 고유 ID 1182897501
# {'카페ID': '1182897501', '카페이름': '파티세리후르츠', '방문자리뷰': '261', '블로그리뷰': '303', '주소': '서울 성동구 아차산로5길 37-1 1층'}
# KANTO 성수
# 카페 고유 ID 1200806667
# {'카페ID': '1200806667', '카페이름': 'KANTO 성수', '방문자리뷰': '336', '블로그리뷰': '303', '주소': '서울 성동구 연무장길 20 지하1층'}
# 본노엘 성수점
# 카페 고유 ID 36237493
# {'카페ID': '36237493', '카페이름': '본노엘 성수점', '방문자리뷰': '1686', '블로그리뷰': '181', '주소': '서울 성동구 상원길 64 1층'}
# 키베이커리
# 카페 고유 ID 1193907072
# {'카페ID': '1193907072', '카페이름': '키베이커리', '방문자리뷰': '622', '블로그리뷰': '181', '주소': '서울 성동구 성수일로 11-2'}
# 비도커피
# 카페 고유 ID 1670214092
# {'카페ID': '1670214092', '카페이름': '비도커피', '방문자리뷰': '194', '블로그리뷰': '147', '주소': '서울 성동구 왕십리로4길 24-7 2층'}
# 노아베이커리 성수
# 카페 고유 ID 1470489200
# {'카페ID': '1470489200', '카페이름': '노아베이커리 성수', '방문자리뷰': '531', '블로그리뷰': '77', '주소': '서울 성동구 연무장5길 19 1층'}
# 올댓커피 포레스트점
# 카페 고유 ID 1483409913
# {'카페ID': '1483409913', '카페이름': '올댓커피 포레스트점', '방문자리뷰': '607', '블로그리뷰': '561', '주소': '서울 성동구 서울숲4길 12-23'}
# 카멜커피 7호점
# 카페 고유 ID 1353346572
# {'카페ID': '1353346572', '카페이름': '카멜커피 7호점', '방문자리뷰': '883', '블로그리뷰': '806', '주소': '서울 성동구 서울숲7길 4 카멜커피'}
# 뵈르에코
# 카페 고유 ID 1781253700
# {'카페ID': '1781253700', '카페이름': '뵈르에코', '방문자리뷰': '71', '블로그리뷰': '355', '주소': '서울 성동구 성수이로16길 33 1층, 지하1층'}
# 도렐 성수점
# 카페 고유 ID 1432336976
# {'카페ID': '1432336976', '카페이름': '도렐 성수점', '방문자리뷰': '1865', '블로그리뷰': '919', '주소': '서울 성동구 연무장7길 11 1층 도렐 성수점'}
# 위스위츠 서울숲
# 카페 고유 ID 1158988360
# {'카페ID': '1158988360', '카페이름': '위스위츠 서울숲', '방문자리뷰': '136', '블로그리뷰': '20', '주소': '서울 성동구 서울숲2길 11-12 1층'}
# 젠젠 성수점
# 카페 고유 ID 1790076538
# {'카페ID': '1790076538', '카페이름': '젠젠 성수점', '방문자리뷰': '906', '블로그리뷰': '191', '주소': '서울 성동구 연무장11길 10 우리큐브 빌딩 1층 젠젠카페'}
# 맛차차
# 카페 고유 ID 1467953783
# {'카페ID': '1467953783', '카페이름': '맛차차', '방문자리뷰': '956', '블로그리뷰': '751', '주소': '서울 성동구 서울숲2길 18-11 1층'}
# 봇봇봇
# 카페 고유 ID 1343525582
# {'카페ID': '1343525582', '카페이름': '봇봇봇', '방문자리뷰': '773', '블로그리뷰': '746', '주소': '서울 성동구 아차산로9길 8'}
# 카페온화 성수점
# 카페 고유 ID 1321493330
# {'카페ID': '1321493330', '카페이름': '카페온화 성수점', '방문자리뷰': '765', '블로그리뷰': '822', '주소': '서울 성동구 아차산로 78 1층'}
# 버니타운
# 카페 고유 ID 1595247698
# {'카페ID': '1595247698', '카페이름': '버니타운', '방문자리뷰': '441', '블로그리뷰': '283', '주소': '서울 성동구 서울숲2길 15-12 1.5층'}
# 구테로이테 성수센트럴키친
# 카페 고유 ID 1046248956
# {'카페ID': '1046248956', '카페이름': '구테로이테 성수센트럴키친', '방문자리뷰': '283', '블로그리뷰': '159', '주소': '서울 성동구 연무장13길 9 1층'}
# 웨스턴챕터
# 카페 고유 ID 1653885354
# {'카페ID': '1653885354', '카페이름': '웨스턴챕터', '방문자리뷰': '842', '블로그리뷰': '314', '주소': '서울 성동구 서울숲2길 12-8 2층'}
# 이월로스터스 성수점
# 카페 고유 ID 1645816805
# {'카페ID': '1645816805', '카페이름': '이월로스터스 성수점', '방문자리뷰': '562', '블로그리뷰': '222', '주소': '서울 성동구 서울숲2길 46 2층 이월로스터스 성수점'}
# 높은산
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 마크69
# 카페 고유 ID 1430646260
# {'카페ID': '1430646260', '카페이름': '마크69', '방문자리뷰': '617', '블로그리뷰': '222', '주소': '서울 성동구 서울숲길 24'}
# 예빈당
# 카페 고유 ID 11861121
# {'카페ID': '11861121', '카페이름': '예빈당', '방문자리뷰': '1209', '블로그리뷰': '268', '주소': '서울 성동구 성수이로 87 성문빌딩 1층'}
# FINZ
# 카페 고유 ID 1621508044
# {'카페ID': '1621508044', '카페이름': 'FINZ', '방문자리뷰': '166', '블로그리뷰': '139', '주소': '서울 성동구 성수일로3길 4-13'}
# 어피스앤드피스
# 카페 고유 ID 1447612432
# {'카페ID': '1447612432', '카페이름': '어피스앤드피스', '방문자리뷰': '130', '블로그리뷰': '135', '주소': '서울 성동구 성수일로12길 17 1층 A Piece & Peace'}
# 에빠
# 카페 고유 ID 1213716626
# {'카페ID': '1213716626', '카페이름': '에빠', '방문자리뷰': '141', '블로그리뷰': '148', '주소': '서울 성동구 왕십리로5길 19 Etba seoul'}
# 글로우
# 카페 고유 ID 548365578
# {'카페ID': '548365578', '카페이름': '글로우', '방문자리뷰': '1650', '블로그리뷰': '1005', '주소': '서울 성동구 아차산로9길 20 1층'}
# 컴포트라피
# 카페 고유 ID 1772537875
# {'카페ID': '1772537875', '카페이름': '컴포트라피', '방문자리뷰': '51', '블로그리뷰': '9', '주소': '서울 성동구 뚝섬로1길 53-1 지1층'}
# 보마켓 서울숲점
# 카페 고유 ID 1479215721
# {'카페ID': '1479215721', '카페이름': '보마켓 서울숲점', '방문자리뷰': '1872', '블로그리뷰': '791', '주소': '서울 성동구 왕십리로 83-21'}
# 성수지앵협동조합
# 카페 고유 ID 1901330939
# {'카페ID': '1901330939', '카페이름': '성수지앵협동조합', '방문자리뷰': '477', '블로그리뷰': '791', '주소': '서울 성동구 왕십리로 101'}
# BNHR
# 카페 고유 ID 1223354536
# {'카페ID': '1223354536', '카페이름': 'BNHR', '방문자리뷰': '734', '블로그리뷰': '791', '주소': '서울 성동구 연무장5길 9-16 1층'}
# 포레스트
# 카페 고유 ID 37009396
# {'카페ID': '37009396', '카페이름': '포레스트', '방문자리뷰': '3082', '블로그리뷰': '791', '주소': '경기 화성시 동탄공원로2길 33-9 1층'}
# 에펜즈
# 카페 고유 ID 82935618
# {'카페ID': '82935618', '카페이름': '에펜즈', '방문자리뷰': '406', '블로그리뷰': '498', '주소': '서울 성동구 서울숲2길 24-8 1층,2층'}
# 로우키
# 카페 고유 ID 1393890643
# {'카페ID': '1393890643', '카페이름': '로우키', '방문자리뷰': '893', '블로그리뷰': '931', '주소': '서울 성동구 연무장3길 6 1층, B1층'}
# 이트앤드링크
# 카페 고유 ID 1483166635
# {'카페ID': '1483166635', '카페이름': '이트앤드링크', '방문자리뷰': '231', '블로그리뷰': '45', '주소': '서울 성동구 성수일로8길 39-1 이트앤드링크'}
# 기미사 성수
# 카페 고유 ID 1088009411
# {'카페ID': '1088009411', '카페이름': '기미사 성수', '방문자리뷰': '292', '블로그리뷰': '195', '주소': '서울 성동구 성수이로26길 47 1층, 지하1층'}
# 올드타운
# 카페 고유 ID 1856267449
# {'카페ID': '1856267449', '카페이름': '올드타운', '방문자리뷰': '1464', '블로그리뷰': '397', '주소': '인천 부평구 길주로565번길 7-5 101호'}
# 카페 차 성수점
# 카페 고유 ID 1203115921
# {'카페ID': '1203115921', '카페이름': '카페 차 성수점', '방문자리뷰': '1354', '블로그리뷰': '397', '주소': '서울 성동구 서울숲6길 2 1층'}
# 에이치커피로스터스
# 카페 고유 ID 1275922607
# {'카페ID': '1275922607', '카페이름': '에이치커피로스터스', '방문자리뷰': '106', '블로그리뷰': '107', '주소': '서울 성동구 성수일로11길 10 1층'}
# 코트사이드
# 카페 고유 ID 1471112751
# {'카페ID': '1471112751', '카페이름': '코트사이드', '방문자리뷰': '138', '블로그리뷰': '240', '주소': '서울 성동구 아차산로13길 2 3F'}
# 포동푸딩
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 제1의맛집
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 훔볼트
# 카페 고유 ID 1504347953
# {'카페ID': '1504347953', '카페이름': '훔볼트', '방문자리뷰': '2016', '블로그리뷰': '467', '주소': '서울 성동구 성수이로 58 1층 HUMBOLT'}
# 미디엄스톤 성수점
# 카페 고유 ID 1477788445
# {'카페ID': '1477788445', '카페이름': '미디엄스톤 성수점', '방문자리뷰': '823', '블로그리뷰': '368', '주소': '서울 성동구 왕십리로10길 18-1 1.5층 미디엄스톤'}
# 아후 Ahoo
# 카페 고유 ID 1912626916
# {'카페ID': '1912626916', '카페이름': '아후 Ahoo', '방문자리뷰': '103', '블로그리뷰': '32', '주소': '서울 성동구 뚝섬로 341-18 1층(성수동1가)'}
# 컴오프
# 카페 고유 ID 1681576115
# {'카페ID': '1681576115', '카페이름': '컴오프', '방문자리뷰': '802', '블로그리뷰': '32', '주소': '서울 성동구 서울숲4길 17 1층'}
# 맥코이 성수
# 카페 고유 ID 1739673389
# {'카페ID': '1739673389', '카페이름': '맥코이 성수', '방문자리뷰': '137', '블로그리뷰': '111', '주소': '서울 성동구 연무장15길 11 에스팩토리 B동 1F'}
# 구펠
# 카페 고유 ID 1411397842
# {'카페ID': '1411397842', '카페이름': '구펠', '방문자리뷰': '760', '블로그리뷰': '213', '주소': '서울 성동구 왕십리로14길 30-1 1층 2층 3층 지하1층'}
# 메쉬커피
# 카페 고유 ID 36276169
# {'카페ID': '36276169', '카페이름': '메쉬커피', '방문자리뷰': '277', '블로그리뷰': '213', '주소': '서울 성동구 서울숲길 43 1층'}
# 아가젤라또 성수
# 카페 고유 ID 1710015927
# {'카페ID': '1710015927', '카페이름': '아가젤라또 성수', '방문자리뷰': '230', '블로그리뷰': '133', '주소': '서울 성동구 연무장길 41-19 지1층 B101호'}
# 올더어글리쿠키&사부아페어
# 카페 고유 ID 1831566455
# {'카페ID': '1831566455', '카페이름': '올더어글리쿠키&사부아페어', '방문자리뷰': '462', '블로그리뷰': '321', '주소': '서울 성동구 성수이로12길 13 1층'}
# 르셀
# 카페 고유 ID 1545903529
# {'카페ID': '1545903529', '카페이름': '르셀', '방문자리뷰': '447', '블로그리뷰': '133', '주소': '서울 성동구 상원10길 25'}
# 어커
# 카페 고유 ID 1560084717
# {'카페ID': '1560084717', '카페이름': '어커', '방문자리뷰': '112', '블로그리뷰': '134', '주소': '서울 성동구 광나루로4길 12 어커'}
# TEESSERT
# 카페 고유 ID 1765973708
# {'카페ID': '1765973708', '카페이름': 'TEESSERT', '방문자리뷰': '143', '블로그리뷰': '159', '주소': '서울 성동구 아차산로 126 지상동 1층 105호(성수동2가, 더리 브 세종타워)'}
# 시나본 서울숲점
# 카페 고유 ID 1470307602
# {'카페ID': '1470307602', '카페이름': '시나본 서울숲점', '방문자리뷰': '1599', '블로그리뷰': '150', '주소': '서울 성동구 서울숲2길 32-14 갤러리아포레 1층'}
# 모리티아
# 카페 고유 ID 37077195
# {'카페ID': '37077195', '카페이름': '모리티아', '방문자리뷰': '554', '블로그리뷰': '475', '주소': '서울 성동구 아차산로5길 10 1층 모리티아'}
# villa.1990
# 카페 고유 ID 1624530576
# {'카페ID': '1624530576', '카페이름': 'villa.1990', '방문자리뷰': '174', '블로그리뷰': '101', '주소': '서울 성동구 둘레9길 17 2층'}
# 아방베이커리 서울숲점
# 카페 고유 ID 1087183871
# {'카페ID': '1087183871', '카페이름': '아방베이커리 서울숲점', '방문자리뷰': '1612', '블로그리뷰': '308', '주소': '서울 성동구 왕십리로 83-21 지하1층 B117호~120호'}
# 모센즈스위트 성수점
# 카페 고유 ID 1709396208
# {'카페ID': '1709396208', '카페이름': '모센즈스위트 성수점', '방문자리뷰': '364', '블로그리뷰': '268', '주소': '서울 성동구 성수이로7길 1 1층'}
# 밀카페 우프
# 카페 고유 ID 1161152347
# {'카페ID': '1161152347', '카페이름': '밀카페 우프', '방문자리뷰': '180', '블로그리뷰': '173', '주소': '서울 성동구 서울숲4길 16-19 2층'}
# 청키드 성수점
# 카페 고유 ID 1944438246
# {'카페ID': '1944438246', '카페이름': '청키드 성수점', '방문자리뷰': '546', '블로그리뷰': '173', '주소': '서울 성동구 아차산로7길 24 1층 1-1호'}
# 라에비뉴
# 카페 고유 ID 1199055314
# {'카페ID': '1199055314', '카페이름': '라에비뉴', '방문자리뷰': '404', '블로그리뷰': '319', '주소': '서울 성동구 성수일로10길 33 1층 103호'}
# 시즈니
# 카페 고유 ID 1388756141
# {'카페ID': '1388756141', '카페이름': '시즈니', '방문자리뷰': '368', '블로그리뷰': '164', '주소': '서울 성동구 서울숲6길 14 거암아트빌라 2층 201호'}
# 어퍼룸
# 카페 고유 ID 1964635228
# {'카페ID': '1964635228', '카페이름': '어퍼룸', '방문자리뷰': '358', '블로그리뷰': '261', '주소': '서울 성동구 성수일로12길 21 1층'}
# 티룸
# 카페 고유 ID 31714576
# {'카페ID': '31714576', '카페이름': '티룸', '방문자리뷰': '310', '블로그리뷰': '47', '주소': '대전 서구 둔산로31번길 28 금정빌딩 8층 윙스터디 대전둔산점'}
# 앵무새루이스
# 카페 고유 ID 1568797034
# {'카페ID': '1568797034', '카페이름': '앵무새루이스', '방문자리뷰': '118', '블로그리뷰': '121', '주소': '서울 성동구 성덕정길 78 3층'}
# 단과자
# 카페 고유 ID 1177180342
# {'카페ID': '1177180342', '카페이름': '단과자', '방문자리뷰': '26', '블로그리뷰': '57', '주소': '서울 성동구 뚝섬로 430 (성수동2가, 2층)'}
# 동빙고 성수점
# 카페 고유 ID 1815284943
# {'카페ID': '1815284943', '카페이름': '동빙고 성수점', '방문자리뷰': '980', '블로그리뷰': '227', '주소': '서울 성동구 서울숲4길 28 1층 동빙고'}
# 웨이크앤베이크 성수
# 카페 고유 ID 1753489603
# {'카페ID': '1753489603', '카페이름': '웨이크앤베이크 성수', '방문자리뷰': '241', '블로그리뷰': '243', '주소': '서울 성동구 서울숲2길 28-12 지하1층'}
# 쏘쏘한 베이킹
# 카페 고유 ID 1867897248
# {'카페ID': '1867897248', '카페이름': '쏘쏘한 베이킹', '방문자리뷰': '366', '블로그리뷰': '55', '주소': '서울 성동구 연무장17길 14 제1층 제101호(성수동2가, 대군인더스타운)'}
# 굴림
# 카페 고유 ID 1397836032
# {'카페ID': '1397836032', '카페이름': '굴림', '방문자리뷰': '377', '블로그리뷰': '55', '주소': '서울 성동구 성수이로5길 1 1층 굴림'}
# 업사이드커피 뚝섬점
# 카페 고유 ID 1906998225
# {'카페ID': '1906998225', '카페이름': '업사이드커피 뚝섬점', '방문자리뷰': '494', '블로그리뷰': '55', '주소': '서울 성동구 왕십리로14길 19-1 1층 업사이드커피'}
# 까사다루아
# 카페 고유 ID 1381920053
# {'카페ID': '1381920053', '카페이름': '까사다루아', '방문자리뷰': '179', '블로그리뷰': '88', '주소': '서울 성동구 성덕정길 66 1층'}
# 코타티 성수점
# 카페 고유 ID 1268717405
# {'카페ID': '1268717405', '카페이름': '코타티 성수점', '방문자리뷰': '51', '블로그리뷰': '264', '주소': '서울 성동구 상원4길 10'}
# Pauline CoffeeBar
# 카페 고유 ID 1215237779
# {'카페ID': '1215237779', '카페이름': 'Pauline CoffeeBar', '방문자리뷰': '292', '블로그리뷰': '228', '주소': '서울 성동구 연무장3길 13 폴린커피바'}
# 당도
# 카페 고유 ID 1469082415
# {'카페ID': '1469082415', '카페이름': '당도', '방문자리뷰': '113', '블로그리뷰': '5', '주소': '충남 서산시 예천1로 28 유플라자 1층'}
# 보난자 베이커리
# 카페 고유 ID 34937369
# {'카페ID': '34937369', '카페이름': '보난자 베이커리', '방문자리뷰': '391', '블로그리뷰': '5', '주소': '서울 성동구 왕십리로5길 9-2'}
# 스타벅스 성수역점
# 카페 고유 ID 270473240
# {'카페ID': '270473240', '카페이름': '스타벅스 성수역점', '방문자리뷰': '6957', '블로그리뷰': '5', '주소': '서울 성동구 성수이로 94'}
# 하루앤원데이
# 카페 고유 ID 38692829
# {'카페ID': '38692829', '카페이름': '하루앤원데이', '방문자리뷰': '2125', '블로그리뷰': '328', '주소': '서울 성동구 아차산로 92 S타워 1층'}
# 오색칠
# 카페 고유 ID 1896147371
# {'카페ID': '1896147371', '카페이름': '오색칠', '방문자리뷰': '130', '블로그리뷰': '321', '주소': '서울 성동구 성수이로 77 1층'}
# 309디저트카페
# 카페 고유 ID 1370339688
# {'카페ID': '1370339688', '카페이름': '309디저트카페', '방문자리뷰': '200', '블로그리뷰': '321', '주소': '서울 성동구 성수이로7길 24 1층'}
# 아쿠아산타 서울숲카페
# 카페 고유 ID 1650180202
# {'카페ID': '1650180202', '카페이름': '아쿠아산타 서울숲카페', '방문자리뷰': '314', '블로그리뷰': '296', '주소': '서울 성동구 상원6길 5-1 4층'}
# 비통레브 르알레스카
# 카페 고유 ID 1765506183
# {'카페ID': '1765506183', '카페이름': '비통레브 르알레스카', '방문자리뷰': '182', '블로그리뷰': '144', '주소': '서울 성동구 연무장길 20-1'}
# 엘레멘츠
# 카페 고유 ID 1678617330
# {'카페ID': '1678617330', '카페이름': '엘레멘츠', '방문자리뷰': '223', '블로그리뷰': '136', '주소': '서울 성동구 성수이로14길 15'}
# 에이테이블 성수점
# 카페 고유 ID 1787967774
# {'카페ID': '1787967774', '카페이름': '에이테이블 성수점', '방문자리뷰': '76', '블로그리뷰': '72', '주소': '서울 성동구 아차산로13길 42 1층'}
# 코스모스상점
# 카페 고유 ID 36905757
# {'카페ID': '36905757', '카페이름': '코스모스상점', '방문자리뷰': '198', '블로그리뷰': '72', '주소': '서울 성동구 성수이로7길 27 서울숲코오롱디지탈타워 1층'}
# 201호
# 카페 고유 ID 1150528971
# {'카페ID': '1150528971', '카페이름': '201호', '방문자리뷰': '459', '블로그리뷰': '1001', '주소': '서울 성동구 상원1길 35-14 2층'}
# 37.5 시그니처 성수
# 카페 고유 ID 1618801648
# {'카페ID': '1618801648', '카페이름': '37.5 시그니처 성수', '방문자리뷰': '1004', '블로그리뷰': '870', '주소': '서울 성동구 연무장길 41-19 1,2,3층 37.5 시그니처 성수'}
# 카페요아정
# 카페 고유 ID 1862026206
# {'카페ID': '1862026206', '카페이름': '카페요아정', '방문자리뷰': '289', '블로그리뷰': '83', '주소': '서울 성동구 서울숲4길 21 지하1층'}
# 서울바나나
# 카페 고유 ID 1281821449
# {'카페ID': '1281821449', '카페이름': '서울바나나', '방문자리뷰': '1143', '블로그리뷰': '183', '주소': '서울 성동구 왕십리로5길 11 1층'}
# 소소하게
# 카페 고유 ID 1966636931
# {'카페ID': '1966636931', '카페이름': '소소하게', '방문자리뷰': '27', '블로그리뷰': '12', '주소': '서울 성동구 성덕정길 27 소소하게'}
# 강별 성수
# 카페 고유 ID 1814734284
# {'카페ID': '1814734284', '카페이름': '강별 성수', '방문자리뷰': '147', '블로그리뷰': '90', '주소': '서울 성동구 뚝섬로9길 8 3층'}
# 아이오쓰리 성수사거리점
# 카페 고유 ID 1918028699
# {'카페ID': '1918028699', '카페이름': '아이오쓰리 성수사거리점', '방문자리뷰': '795', '블로그리뷰': '137', '주소': '서울 성동구 성수이로20길 60 1층'}
# 플래드 카페
# 카페 고유 ID 1644681219
# {'카페ID': '1644681219', '카페이름': '플래드 카페', '방문자리뷰': '151', '블로그리뷰': '139', '주소': '서울 성동구 서울숲2길 12-7 1층'}
# stdo
# 카페 고유 ID 1282311574
# {'카페ID': '1282311574', '카페이름': 'stdo', '방문자리뷰': '1545', '블로그리뷰': '237', '주소': '서울 성동구 서울숲4길 12-8 1층'}
# 프라이데이무브먼트
# 카페 고유 ID 37302046
# {'카페ID': '37302046', '카페이름': '프라이데이무브먼트', '방문자리뷰': '299', '블로그리뷰': '241', '주소': '서울 성동구 왕십리로14길 7 1층 프라이데이무브먼트'}
# camouflage coffee
# 카페 고유 ID 1505046001
# {'카페ID': '1505046001', '카페이름': 'camouflage coffee', '방문자리뷰': '385', '블로그리뷰': '241', '주소': '서울 성동구 아차산로1길 9'}
# 포도빵집
# 카페 고유 ID 1813154034
# {'카페ID': '1813154034', '카페이름': '포도빵집', '방문자리뷰': '182', '블로그리뷰': '73', '주소': '서울 성동구 서울숲7길 9-1 1층 포도빵집'}
# 디데이크
# 카페 고유 ID 1776483115
# {'카페ID': '1776483115', '카페이름': '디데이크', '방문자리뷰': '52', '블로그리뷰': '11', '주소': '서울 성동구 뚝섬로9길 16 3층 302호'}
# 피어커피
# 카페 고유 ID 33704135
# {'카페ID': '33704135', '카페이름': '피어커피', '방문자리뷰': '378', '블로그리뷰': '11', '주소': '서울 성동구 광나루로4가길 24 1층 피어커피'}
# 스윗바이브
# 카페 고유 ID 1847066597
# {'카페ID': '1847066597', '카페이름': '스윗바이브', '방문자리뷰': '213', '블로그리뷰': '105', '주소': '서울 성동구 왕십리로4길 26-18 2F'}
# 오버도즈도넛앤커피 성수
# 카페 고유 ID 1085084433
# {'카페ID': '1085084433', '카페이름': '오버도즈도넛앤커피 성수', '방문자리뷰': '939', '블로그리뷰': '326', '주소': '서울 성동구 왕십리로10길 19 1층'}
# 인덱스카라멜
# 카페 고유 ID 1532726506
# {'카페ID': '1532726506', '카페이름': '인덱스카라멜', '방문자리뷰': '535', '블로그리뷰': '326', '주소': '서울 성동구 성수이로14길 14 1층 index caramel'}
# 아이오쓰리 에이스하이엔드점
# 카페 고유 ID 1623328599
# {'카페ID': '1623328599', '카페이름': '아이오쓰리 에이스하이엔드점', '방문자리뷰': '954', '블로그리뷰': '153', '주소': '서울 성동구 성수이로10길 14 103호 아이오쓰리'}
# 샌드카베
# 카페 고유 ID 1610448119
# {'카페ID': '1610448119', '카페이름': '샌드카베', '방문자리뷰': '172', '블로그리뷰': '151', '주소': '서울 성동구 서울숲4길 22-18 1층 카페'}
# 메종 파이프그라운드
# 카페 고유 ID 1244479891
# {'카페ID': '1244479891', '카페이름': '메종 파이프그라운드', '방문자리뷰': '1401', '블로그리뷰': '1437', '주소': '서울 성동구 왕십리로 83-21 지하1층 B124호, B125호'}
# 아이아이알
# 카페 고유 ID 1270448451
# {'카페ID': '1270448451', '카페이름': '아이아이알', '방문자리뷰': '81', '블로그리뷰': '101', '주소': '서울 성동구 성수일로 13'}
# 카페 이페메라 LCDC SEOUL
# 카페 고유 ID 1418458318
# {'카페ID': '1418458318', '카페이름': '카페 이페메라 LCDC SEOUL', '방문자리뷰': '434', '블로그리뷰': '254', '주소': '서울 성동구 연무장17길 10 LCDC SEOUL A동 1층'}
# 올데이휘낭시에 성수점
# 카페 고유 ID 1070814255
# {'카페ID': '1070814255', '카페이름': '올데이휘낭시에 성수점', '방문자리뷰': '104', '블로그리뷰': '46', '주소': '서울 성동구 성수이로16길 48 1층'}
# 하우트제곱
# 카페 고유 ID 1824541032
# {'카페ID': '1824541032', '카페이름': '하우트제곱', '방문자리뷰': '108', '블로그리뷰': '129', '주소': '서울 성동구 뚝섬로9길 3-1 1층'}
# 에이피피피
# 카페 고유 ID 1082720957
# {'카페ID': '1082720957', '카페이름': '에이피피피', '방문자리뷰': '196', '블로그리뷰': '68', '주소': '서울 성동구 뚝섬로9길 10 1~3층'}
# 밀키샵 성수점
# 카페 고유 ID 1407198399
# {'카페ID': '1407198399', '카페이름': '밀키샵 성수점', '방문자리뷰': '203', '블로그리뷰': '182', '주소': '서울 성동구 연무장길 17 1층'}
# 크로플다일 본점
# 카페 고유 ID 1111815018
# {'카페ID': '1111815018', '카페이름': '크로플다일 본점', '방문자리뷰': '179', '블로그리뷰': '144', '주소': '서울 성동구 왕십리로 96-1 1층, 2층'}
# 앤드밀 성수점
# 카페 고유 ID 1943210266
# {'카페ID': '1943210266', '카페이름': '앤드밀 성수점', '방문자리뷰': '1587', '블로그리뷰': '144', '주소': '서울 성동구 연무장3길 5-1 3층'}
# 카페 포제
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 올드너티 커피로스터스
# 카페 고유 ID 1078949657
# {'카페ID': '1078949657', '카페이름': '올드너티 커피로스터스', '방문자리뷰': '175', '블로그리뷰': '140', '주소': '서울 성동구 광나루로2길 23-1 1층'}
# 복식커피
# 카페 고유 ID 1563091642
# {'카페ID': '1563091642', '카페이름': '복식커피', '방문자리뷰': '155', '블로그리뷰': '73', '주소': '서울 성동구 성덕정3길 7-1 1층'}
# 마야마야 북 & 라이프 카페
# 카페 고유 ID 1197323511
# {'카페ID': '1197323511', '카페이름': '마야마야 북 & 라이프 카페', '방문자리뷰': '33', '블로그리뷰': '25', '주소': '서울 성동구 서울숲2길 24-7 1, 2층'}
# 어글리크림치즈
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 뚜르띠에르
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 타크
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 글레이셔박
# 카페 고유 ID 1936568550
# {'카페ID': '1936568550', '카페이름': '글레이셔박', '방문자리뷰': '482', '블로그리뷰': '191', '주소': '서울 성동구 서울숲2길 9'}
# 버치커피
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# RSG 성수
# 카페 고유 ID 1279085531
# {'카페ID': '1279085531', '카페이름': 'RSG 성수', '방문자리뷰': '28', '블로그리뷰': '212', '주소': '서울 성동구 연무장15길 11 C동 110호'}
# 프라이데이 베이커리
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 폴인레미유 성수점
# 카페 고유 ID 1465772360
# {'카페ID': '1465772360', '카페이름': '폴인레미유 성수점', '방문자리뷰': '776', '블로그리뷰': '541', '주소': '서울 성동구 왕십리로14길 34-8'}
# 투썸플레이스 서울숲역점
# 카페 고유 ID 1743679102
# {'카페ID': '1743679102', '카페이름': '투썸플레이스 서울숲역점', '방문자리뷰': '1578', '블로그리뷰': '541', '주소': '서울 성동구 왕십리로 58 101호, 201호'}
# 네모네
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# DYI WORKSHOP
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 인치스
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 글리터
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 오프커피
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 시슬러스
# 카페 고유 ID 1121816274
# {'카페ID': '1121816274', '카페이름': '시슬러스', '방문자리뷰': '130', '블로그리뷰': '64', '주소': '서울 성동구 왕십리로5길 19 1층 뒷쪽 주차장 제일 안쪽 주황색 테이블있는 곳'}
# 백야드빌더성수
# 카페 고유 ID 1271468163
# {'카페ID': '1271468163', '카페이름': '백야드빌더성수', '방문자리뷰': '73', '블로그리뷰': '138', '주소': '서울 성동구 광나루로 152'}
# 히즈빈스 성수점
# 카페 고유 ID 1103507675
# {'카페ID': '1103507675', '카페이름': '히즈빈스 성수점', '방문자리뷰': '555', '블로그리뷰': '138', '주소': '서울 성동구 왕십리로2길 20 1층 (성수동1가)'}
# 빌로위 성수
# 카페 고유 ID 1184596405
# {'카페ID': '1184596405', '카페이름': '빌로위 성수', '방문자리뷰': '115', '블로그리뷰': '136', '주소': '서울 성동구 성수일로12길 15 1층'}
# 래뮤
# 카페 고유 ID 1076715606
# {'카페ID': '1076715606', '카페이름': '래뮤', '방문자리뷰': '221', '블로그리뷰': '125', '주소': '서울 성동구 연무장길 14 2층(성수동1가)'}
# 올로
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 성수동 수제모찌
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 투썸플레이스 성수skv타워점
# 카페 고유 ID 1850384974
# {'카페ID': '1850384974', '카페이름': '투썸플레이스 성수skv타워점', '방문자리뷰': '1963', '블로그리뷰': '45', '주소': '서울 성동구 연무장5가길 25'}
# 그레인바운더리 성수점
# 카페 고유 ID 1983922131
# {'카페ID': '1983922131', '카페이름': '그레인바운더리 성수점', '방문자리뷰': '339', '블로그리뷰': '145', '주소': '서울 성동구 아차산로 66 1층'}
# 피리어드
# 카페 고유 ID 1000212289
# {'카페ID': '1000212289', '카페이름': '피리어드', '방문자리뷰': '157', '블로그리뷰': '81', '주소': '서울 성동구 서울숲2길 19-17 1층 피리어드'}
# 메이플탑
# 카페 고유 ID 1184862139
# {'카페ID': '1184862139', '카페이름': '메이플탑', '방문자리뷰': '1669', '블로그리뷰': '81', '주소': '서울 성동구 성수이로14길 14 성수연방 A동 2층'}
# 성수미술관
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 어페어커피
# 카페 고유 ID 1863706992
# {'카페ID': '1863706992', '카페이름': '어페어커피', '방문자리뷰': '159', '블로그리뷰': '174', '주소': '서울 성동구 성수이로6길 11 1층 어페어 커피'}
# 소울레터커피컴퍼니
# 카페 고유 ID 1530501406
# {'카페ID': '1530501406', '카페이름': '소울레터커피컴퍼니', '방문자리뷰': '350', '블로그리뷰': '305', '주소': '서울 성동구 상원12길 20-14 1층 소울레터커피'}
# 로우커피스탠드 성수점
# 카페 고유 ID 1404930910
# {'카페ID': '1404930910', '카페이름': '로우커피스탠드 성수점', '방문자리뷰': '544', '블로그리뷰': '173', '주소': '서울 성동구 연무장길 94 1층'}
# 어썸블리스
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 플로피
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 리옹베이커리
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 스타벅스 서울숲역점
# 카페 고유 ID 1384891709
# {'카페ID': '1384891709', '카페이름': '스타벅스 서울숲역점', '방문자리뷰': '5526', '블로그리뷰': '173', '주소': '서울 성동구 왕십리로 50'}
# 한나 성수점
# 카페 고유 ID 1452864260
# {'카페ID': '1452864260', '카페이름': '한나 성수점', '방문자리뷰': '25', '블로그리뷰': '19', '주소': '서울 성동구 둘레7길 15 1층'}
# 커피식탁
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 푸르너스가든 서울숲
# 카페 고유 ID 34786556
# {'카페ID': '34786556', '카페이름': '푸르너스가든 서울숲', '방문자리뷰': '1107', '블로그리뷰': '19', '주소': '서울 성동구 서울숲2길 46-9'}
# 그리디힙히크
# 카페 고유 ID 1175554452
# {'카페ID': '1175554452', '카페이름': '그리디힙히크', '방문자리뷰': '66', '블로그리뷰': '3', '주소': '서울 성동구 아차산로1길 9 1층 그리디 힙히크'}
# 카페 해피캠퍼
# 카페 고유 ID 1967654360
# {'카페ID': '1967654360', '카페이름': '카페 해피캠퍼', '방문자리뷰': '137', '블로그리뷰': '25', '주소': '서울 성동구 왕십리로4길 10-15 1층'}
# 데우스 카페 성수점
# 카페 고유 ID 1673773985
# {'카페ID': '1673773985', '카페이름': '데우스 카페 성수점', '방문자리뷰': '367', '블로그리뷰': '150', '주소': '서울 성동구 연무장3길 21 1층 102호'}
# 위키드와이프 페어링바 & 까페스토크
# 카페 고유 ID 1075944179
# {'카페ID': '1075944179', '카페이름': '위키드와이프 페어링바 & 까페스토크', '방문자리뷰': '158', '블로그리뷰': '222', '주소': '서울 성동구 성수일로 1 1층'}
# 훌로훌로케이크
# 카페 고유 ID 1291534060
# {'카페ID': '1291534060', '카페이름': '훌로훌로케이크', '방문자리뷰': '33', '블로그리뷰': '34', '주소': '서울 성동구 성수이로6길 11 1층 훌로훌로케이크'}
# DYCAFE
# 카페 고유 ID 1892371038
# {'카페ID': '1892371038', '카페이름': 'DYCAFE', '방문자리뷰': '79', '블로그리뷰': '119', '주소': '서울 성동구 광나루로6길 7 1층'}
# 브로벨커피
# 카페 고유 ID 1428046376
# {'카페ID': '1428046376', '카페이름': '브로벨커피', '방문자리뷰': '133', '블로그리뷰': '155', '주소': '서울 성동구 뚝섬로 413 1층 브로벨커피'}
# KROW
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 오거트
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 퀸테트
# 카페 고유 ID 1266915975
# {'카페ID': '1266915975', '카페이름': '퀸테트', '방문자리뷰': '100', '블로그리뷰': '117', '주소': '서울 성동구 서울숲2길 12-8 1층'}
# 에토프커피 성수
# 카페 고유 ID 1605963127
# {'카페ID': '1605963127', '카페이름': '에토프커피 성수', '방문자리뷰': '131', '블로그리뷰': '72', '주소': '서울 성동구 왕십리로8길 8 2층'}
# 에그마카슈 성수
# 카페 고유 ID 1413106151
# {'카페ID': '1413106151', '카페이름': '에그마카슈 성수', '방문자리뷰': '154', '블로그리뷰': '72', '주소': '서울 성동구 상원6나길 14 101호'}
# 스탠드업플리즈바이턴온
# 카페 고유 ID 1306390433
# {'카페ID': '1306390433', '카페이름': '스탠드업플리즈바이턴온', '방문자리뷰': '241', '블로그리뷰': '375', '주소': '서울 성동구 연무장3길 14 1층2호'}
# 위켄드피크닉
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 앳이즈
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 헤이숲
# 카페 고유 ID 1008108835
# {'카페ID': '1008108835', '카페이름': '헤이숲', '방문자리뷰': '21', '블로그리뷰': '20', '주소': '서울 성동구 성수이로7길 38 1층 101호'}
# 스타벅스 뚝섬역점
# 카페 고유 ID 1725861030
# {'카페ID': '1725861030', '카페이름': '스타벅스 뚝섬역점', '방문자리뷰': '6830', '블로그리뷰': '173', '주소': '서울 성동구 아차산로 42'}
# 와이덴 성수
# 카페 고유 ID 1982767346
# {'카페ID': '1982767346', '카페이름': '와이덴 성수', '방문자리뷰': '201', '블로그리뷰': '76', '주소': '서울 성동구 성수일로12길 34 1층 와이덴'}
# 온에떼라
# 카페 고유 ID 1367477098
# {'카페ID': '1367477098', '카페이름': '온에떼라', '방문자리뷰': '119', '블로그리뷰': '29', '주소': '서울 성동구 성수일로 111 성수선명스퀘어 제104호'}
# 하우스 오브 지알
# 카페 고유 ID 1688607352
# {'카페ID': '1688607352', '카페이름': '하우스 오브 지알', '방문자리뷰': '1', '블로그리뷰': '32', '주소': '서울 성동구 서울숲2길 20-1'}
# 투데이즈이너프
# 카페 고유 ID 1078138614
# {'카페ID': '1078138614', '카페이름': '투데이즈이너프', '방문자리뷰': '216', '블로그리뷰': '107', '주소': '서울 성동구 서울숲2길 44-13 지하1층'}
# 리커버리커피바
# 카페 고유 ID 1576185695
# {'카페ID': '1576185695', '카페이름': '리커버리커피바', '방문자리뷰': '101', '블로그리뷰': '107', '주소': '서울 성동구 왕십리로16가길 10 1층'}
# 바버앤젤라또
# 카페 고유 ID 1542245379
# {'카페ID': '1542245379', '카페이름': '바버앤젤라또', '방문자리뷰': '47', '블로그리뷰': '39', '주소': '서울 성동구 왕십리로4가길 2-9 B1'}
# 수피하우스
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 디 진테제 하이 카페
# 카페 고유 ID 1579197021
# {'카페ID': '1579197021', '카페이름': '디 진테제 하이 카페', '방문자리뷰': '18', '블로그리뷰': '6', '주소': '서울 성동구 왕십리로 115 10층 카페'}
# 사운드프로바이더
# 카페 고유 ID 1839704319
# {'카페ID': '1839704319', '카페이름': '사운드프로바이더', '방문자리뷰': '22', '블로그리뷰': '3', '주소': '서울 성동구 뚝섬로7길 6 2층'}
# 릴레이션 카페
# 카페 고유 ID 1578379657
# {'카페ID': '1578379657', '카페이름': '릴레이션 카페', '방문자리뷰': '148', '블로그리뷰': '154', '주소': '서울 성동구 상원6길 2 1층 RELATION 릴레이션커피'}
# 로우포레스트
# 카페 고유 ID 1019405388
# {'카페ID': '1019405388', '카페이름': '로우포레스트', '방문자리뷰': '177', '블로그리뷰': '180', '주소': '서울 성동구 서울숲길 38 1층'}
# 씨에이크
# 카페 고유 ID 1361054053
# {'카페ID': '1361054053', '카페이름': '씨에이크', '방문자리뷰': '31', '블로그리뷰': '24', '주소': '서울 성동구 왕십리로14길 24 1층'}
# 블루너리
# 카페 고유 ID 1248117249
# {'카페ID': '1248117249', '카페이름': '블루너리', '방문자리뷰': '129', '블로그리뷰': '493', '주소': '서울 성동구 성덕정3길 8 1층 103호(성수동1가)bluenery'}
# 누아흐
# 카페 고유 ID 1055143125
# {'카페ID': '1055143125', '카페이름': '누아흐', '방문자리뷰': '423', '블로그리뷰': '168', '주소': '서울 성동구 성수일로11길 15 뚝섬리버빌1층 카페누아흐'}
# 하이엔드라이
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 메종드마가레뜨
# 카페 고유 ID 1460780062
# {'카페ID': '1460780062', '카페이름': '메종드마가레뜨', '방문자리뷰': '399', '블로그리뷰': '371', '주소': '서울 성동구 연무장3길 14'}
# 쿠키도우즈
# 카페 고유 ID 1711774601
# {'카페ID': '1711774601', '카페이름': '쿠키도우즈', '방문자리뷰': '138', '블로그리뷰': '30', '주소': '서울 성동구 왕십리로14길 25 1층'}
# 리글림 카페 성수점
# 카페 고유 ID 1677244964
# {'카페ID': '1677244964', '카페이름': '리글림 카페 성수점', '방문자리뷰': '151', '블로그리뷰': '73', '주소': '서울 성동구 서울숲2길 8-7 B1'}
# 기댈빙
# 카페 고유 ID 1250235967
# {'카페ID': '1250235967', '카페이름': '기댈빙', '방문자리뷰': '97', '블로그리뷰': '69', '주소': '서울 성동구 성덕정길 47 1층 102호'}
# 탐앤탐스 성수1호점
# 카페 고유 ID 1461908908
# {'카페ID': '1461908908', '카페이름': '탐앤탐스 성수1호점', '방문자리뷰': '926', '블로그리뷰': '26', '주소': '서울 성동구 성수이로 51 1층'}
# 보스코 에스프레소 바
# 카페 고유 ID 1183278977
# {'카페ID': '1183278977', '카페이름': '보스코 에스프레소 바', '방문자리뷰': '418', '블로그리뷰': '262', '주소': '서울 성동구 상원1길 13'}
# 웜히어
# 카페 고유 ID 1182192310
# {'카페ID': '1182192310', '카페이름': '웜히어', '방문자리뷰': '88', '블로그리뷰': '81', '주소': '서울 성동구 상원6가길 3 1층'}
# 커피기업 서울숲점
# 해당 카페에 대한 정보를 수집할 수 없습니다.
# 마르코웤스
# 카페 고유 ID 1320654683
# {'카페ID': '1320654683', '카페이름': '마르코웤스', '방문자리뷰': '216', '블로그리뷰': '81', '주소': '서울 성동구 아차산로11길 26'}
