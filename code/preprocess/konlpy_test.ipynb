# %%
# !pip install konlpy

# %%
# !pip install JPype1

# %%
import pandas as pd
import numpy as np

# %%
from konlpy.tag import Okt

okt = Okt()
text = "안녕하세요. 코엔엘파이 사용법을 알려주세요."
result = okt.pos(text)

print(result)
# Out:
# [('안녕하세요', 'Adjective'), ('.', 'Punctuation'), ('코', 'Noun'), ('엔엘', 'Noun'), ('파이', 'Noun'), ('사', 'Modifier'), ('용법', 'Noun'), ('을', 'Josa'), ('알려주세요', 'Verb'), ('.', 'Punctuation')]

# %%
import os
path= '../../data/blog_review/blog_review_result_list/한남동'
list= os.listdir(path)
list
# Out:
# ['hn_1002440696_blog.csv',
#  'hn_1007633030_blog.csv',
#  'hn_1007939018_blog.csv',
#  'hn_1013810749_blog.csv',
#  'hn_1017448283_blog.csv',
#  'hn_1021898114_blog.csv',
#  'hn_1026191970_blog.csv',
#  'hn_1029619861_blog.csv',
#  'hn_1030067652_blog.csv',
#  'hn_1041846907_blog.csv',
#  'hn_1054912722_blog.csv',
#  'hn_1057800745_blog.csv',
#  'hn_1067440345_blog.csv',
#  'hn_1073547700_blog.csv',
#  'hn_1079753617_blog.csv',
#  'hn_1083291951_blog.csv',
#  'hn_1083396619_blog.csv',
#  'hn_1085204907_blog.csv',
#  'hn_1089116606_blog.csv',
#  'hn_1089811009_blog.csv',
#  'hn_1093337449_blog.csv',
#  'hn_1095495484_blog.csv',
#  'hn_1096865151_blog.csv',
#  'hn_1098863541_blog.csv',
#  'hn_1100009233_blog.csv',
#  'hn_1100276726_blog.csv',
#  'hn_1101891783_blog.csv',
#  'hn_1105084400_blog.csv',
#  'hn_1108285231_blog.csv',
#  'hn_1110133208_blog.csv',
#  'hn_1117238314_blog.csv',
#  'hn_1119648366_blog.csv',
#  'hn_1121122923_blog.csv',
#  'hn_1121894431_blog.csv',
# ...

# %%
blog1= pd.read_csv(path+'/'+list[1])['content'].to_list()
blog1[0]
# Out:
# '내돈내산 맛집 고급 디저트 맛집 한남 살리르 한남동에서 놀다가 후식으로 아이스크림, 젤라또를 먹고 싶어 찾다가 발견한 살리르. 블로그 리뷰 수가 많지 않은 걸 보면 덜 유명한 곳 같은데 조만간 엄청 유명해질 것 같다. 일단 젤라또가 평범하지 않았고, 분위기가 참 독특했기 때문이다. 📍살리르 한 줄 요약 1. 한남동 젤라또 아이스크림 맛집이다. 2. 내부가 협소해 자리를 잘 잡아야 한다. 3. 아이스크림과 함께 와인을 페어링 해 먹을 수 있다. 4. 분위기도 고급스럽고, 유니크하다. 5. 남자 직원분이 친절하게 아이스크림 설명을 해주신다. 6. 어디서 먹어보지 못한 유니크한 아이스크림을 맛볼 수 있다. 살리르 📍주소 : 서울 용산구 이태원로54길 58-20 1층 ☎️전화번호 : 0507-1375-3318 🕘영업시간 : 16:0~24:00 금, 토 16:00~01:00 월, 화 정기휴무 🚘주차 : 불가능 살리르 가는 길 살리르는 한강진역 3번 출구로 나와 EMIS한남 또는 마르디메크르디 매장 근처에 있는 골목으로 들어가면 된다. 간판이 쉽게 보이지 않는 곳이라 잘 찾아가야 한다. SALIR 라고 적힌 곳이 바로 살리르 살리르 골목에는 벽에 이런 간이 테이블도 있었다. 내부가 좁기 때문에 손님이 많을 경우 이곳에서 서서 젤라또를 맛봐도 좋을 것 같다. 살리르 내부 살리르는 와인과 젤라또 아이스크림을 파는 곳으로 부엌 안쪽에는 저장된 와인이 많았다. 자리는 이렇게 벽을 보고 앉을 수 있는 두 개의 자리와 카운터 바 앞에 앉는 자리 그리고, 매장 가운데 위치한 원테이블 자리가 있었다. 최대로 인원을 수용해도 7명쯤..? 10명 정도 수용이 가능해 보였다. 살리르 메뉴판 이달의 아이스크림 메뉴가 있었고, 매달 다른 맛을 맛볼 수 있는게 살리르의 매력이다. 메뉴 이름도 어려웠는데 읽기 힘든 독특한 폰트로 적혀져 있었지만 직원분이 오셔서 메뉴 하나하나 어떤 재료가 들어갔는지 설명해 주셔서 아이스크림을 고르기 쉬웠다. 한남동 아이스크림 맛집 살리르 젤라또 메뉴 설명 영상
# ...

# %%
result = okt.pos(blog1[0])
result
# Out:
# [('내', 'Determiner'),
#  ('돈', 'Noun'),
#  ('내', 'Determiner'),
#  ('산', 'Noun'),
#  ('맛집', 'Noun'),
#  ('고급', 'Noun'),
#  ('디저트', 'Noun'),
#  ('맛집', 'Noun'),
#  ('한남', 'Noun'),
#  ('살리르', 'Noun'),
#  ('한남동', 'Noun'),
#  ('에서', 'Josa'),
#  ('놀다가', 'Verb'),
#  ('후식', 'Noun'),
#  ('으로', 'Josa'),
#  ('아이스크림', 'Noun'),
#  (',', 'Punctuation'),
#  ('젤라또', 'Noun'),
#  ('를', 'Josa'),
#  ('먹고', 'Verb'),
#  ('싶어', 'Verb'),
#  ('찾다가', 'Verb'),
#  ('발견', 'Noun'),
#  ('한', 'Josa'),
#  ('살리르', 'Noun'),
#  ('.', 'Punctuation'),
#  ('블로그', 'Noun'),
#  ('리뷰', 'Noun'),
#  ('수가', 'Noun'),
#  ('많지', 'Adjective'),
#  ('않은', 'Verb'),
#  ('걸', 'Noun'),
#  ('보면', 'Verb'),
#  ('덜', 'Noun'),
#  ('유명한', 'Adjective'),
#  ('곳', 'Noun'),
#  ('같은데', 'Adjective'),
#  ('조만간', 'Noun'),
#  ('엄청', 'Adverb'),
#  ('유명해질', 'Adjective'),
#  ('것', 'Noun'),
#  ('같다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('일단', 'Noun'),
#  ('젤라또', 'Noun'),
#  ('가', 'Josa'),
#  ('평범하지', 'Adjective'),
#  ('않았고', 'Verb'),
# ...

# %%
result
# Out:
# [('안녕하세요', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('코', 'Noun'),
#  ('엔엘', 'Noun'),
#  ('파이', 'Noun'),
#  ('사', 'Modifier'),
#  ('용법', 'Noun'),
#  ('을', 'Josa'),
#  ('알려주세요', 'Verb'),
#  ('.', 'Punctuation')]
