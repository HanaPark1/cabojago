# %% [markdown]
# ### 성수동

# %%
import pandas as pd
import numpy as np
import os

# 드라이브 폴더 경로
path = '../data/blog_review/blog_review_result_list/성수동'

# 폴더 내 파일 리스트 가져오기
files = os.listdir(path)
len(files)
# 파일 리스트 출력
# for file in files:
#     print(f"File Name: {file}")

cafeId= pd.read_csv('../data/output_cafelist/cafe_info_list_seongsu.csv')
len(cafeId)

import re
for file in files[10:]:
    try:
        result = re.search(r'성수동 (.*?)_', file)
        
        if result:
            cafeName = result.group(1)
            print(cafeName)
            
            # cafeId에서 '카페이름'이 cafeName을 포함하는 행 찾기
            matching_rows = cafeId[cafeId['카페이름'].str.contains(cafeName)]
            
            if not matching_rows.empty:
                id = int(matching_rows.iloc[0]['카페ID'])
                new_name = "ss_" + str(id) + "_blog.csv"
                
                old_path = os.path.join(path, file)
                new_path = os.path.join(path, new_name)
                
                os.rename(old_path, new_path)
                print(f"파일 이름 변경: {file} -> {new_name}")
            else:
                print(f"{cafeName}에 해당하는 카페ID가 없습니다.")
                old_path = os.path.join(path, file)
                os.remove(old_path)
                
        else:
            print(f"정규표현식 매칭 실패: {file}")
    except Exception as e:
        print(f"에러 발생: {e}")
# Out:
# 정규표현식 매칭 실패: hn_1259420360_blog.csv
# 정규표현식 매칭 실패: ss_1833313793_blog.csv
# 정규표현식 매칭 실패: ss_1075944179_blog.csv
# 정규표현식 매칭 실패: ss_1465772360_blog.csv
# 정규표현식 매칭 실패: hn_1813154034_blog.csv
# 정규표현식 매칭 실패: ss_1483409913_blog.csv
# 정규표현식 매칭 실패: ss_1765973708_blog.csv
# 정규표현식 매칭 실패: ss_1320654683_blog.csv
# 정규표현식 매칭 실패: ss_1578379657_blog.csv
# 정규표현식 매칭 실패: hn_1399503871_blog.csv
# 정규표현식 매칭 실패: hn_1103507675_blog.csv
# 정규표현식 매칭 실패: ss_1193907072_blog.csv
# 정규표현식 매칭 실패: ss_1193971273_blog.csv
# 정규표현식 매칭 실패: hn_1532726506_blog.csv
# 정규표현식 매칭 실패: hn_1862026206_blog.csv
# 정규표현식 매칭 실패: hn_1247415883_blog.csv
# 정규표현식 매칭 실패: ss_1863706992_blog.csv
# 정규표현식 매칭 실패: ss_1829908685_blog.csv
# 정규표현식 매칭 실패: ss_1776483115_blog.csv
# 정규표현식 매칭 실패: hn_1624336026_blog.csv
# 정규표현식 매칭 실패: ss_1681576115_blog.csv
# 정규표현식 매칭 실패: ss_1411397842_blog.csv
# 정규표현식 매칭 실패: hn_1268717405_blog.csv
# 정규표현식 매칭 실패: ss_1624530576_blog.csv
# 정규표현식 매칭 실패: hn_1621508044_blog.csv
# 정규표현식 매칭 실패: ss_36905757_blog.csv
# ...

# %% [markdown]
# #### 연남동 (추후 데이터 수집 후 다시할 예정)

# %%
# path = '../data/blog_review/blog_review_result_list/연남동'
# # blog= pd.read_csv('../data/blog_review/blog_review_result_list/연남동.csv')
# # 폴더 내 파일 리스트 가져오기
# files = os.listdir(path)
# len(files)

# cafeId= pd.read_csv('../data/output_cafelist/cafe_info_list_yeonnam.csv')
# len(cafeId)

# import re
# for file in files[10:]:
#     try:
#         result = re.search(r'연남동 (.*?)_', file)
        
#         if result:
#             cafeName = result.group(1)
#             print(cafeName)
            
#             # cafeId에서 '카페이름'이 cafeName을 포함하는 행 찾기
#             matching_rows = cafeId[cafeId['카페이름'].str.contains(cafeName)]
            
#             if not matching_rows.empty:
#                 id = int(matching_rows.iloc[0]['카페ID'])
#                 new_name = "yn_" + str(id) + "_blog.csv"
                
#                 old_path = os.path.join(path, file)
#                 new_path = os.path.join(path, new_name)
                
#                 os.rename(old_path, new_path)
#                 print(f"파일 이름 변경: {file} -> {new_name}")
#             else:
#                 print(f"{cafeName}에 해당하는 카페ID가 없습니다.")
#                 old_path = os.path.join(path, file)
#                 os.remove(old_path)
                
#         else:
#             print(f"정규표현식 매칭 실패: {file}")
#     except Exception as e:
#         print(f"에러 발생: {e}")

# %% [markdown]
# #### 연희동

# %%
path = '../data/blog_review/blog_review_result_list/연희동'
# blog= pd.read_csv('../data/blog_review/blog_review_result_list/연남동.csv')
# 폴더 내 파일 리스트 가져오기
files = os.listdir(path)
len(files)

cafeId= pd.read_csv('../data/output_cafelist/cafe_info_list_yeonhee.csv')
len(cafeId)

import re
for file in files[10:]:
    try:
        result = re.search(r'연희동 (.*?)_', file)
        
        if result:
            cafeName = result.group(1)
            print(cafeName)
            
            # cafeId에서 '카페이름'이 cafeName을 포함하는 행 찾기
            matching_rows = cafeId[cafeId['카페이름'].str.contains(cafeName)]
            
            if not matching_rows.empty:
                id = int(matching_rows.iloc[0]['카페ID'])
                new_name = "yh_" + str(id) + "_blog.csv"
                
                old_path = os.path.join(path, file)
                new_path = os.path.join(path, new_name)
                
                os.rename(old_path, new_path)
                print(f"파일 이름 변경: {file} -> {new_name}")
            else:
                print(f"{cafeName}에 해당하는 카페ID가 없습니다.")
                old_path = os.path.join(path, file)
                os.remove(old_path)
                
        else:
            print(f"정규표현식 매칭 실패: {file}")
    except Exception as e:
        print(f"에러 발생: {e}")
# Out:
# 그로밋커피하우스
# 파일 이름 변경: 연희동 그로밋커피하우스_blog_content.csv -> yh_1656206859_blog.csv
# 폴앤폴리나
# 폴앤폴리나에 해당하는 카페ID가 없습니다.
# 금옥당
# 파일 이름 변경: 연희동 금옥당 _blog_content.csv -> yh_1214851981_blog.csv
# 가비노
# 파일 이름 변경: 연희동 가비노_blog_content.csv -> yh_1283239259_blog.csv
# 베베베 신촌점
# 파일 이름 변경: 연희동 베베베 신촌점_blog_content.csv -> yh_1476308702_blog.csv
# 미도파
# 파일 이름 변경: 연희동 미도파_blog_content.csv -> yh_1056913162_blog.csv
# 연희동오븐
# 파일 이름 변경: 연희동 연희동오븐_blog_content.csv -> yh_1410811129_blog.csv
# 카페로이
# 파일 이름 변경: 연희동 카페로이_blog_content.csv -> yh_1357275594_blog.csv
# 전통찻집다향
# 파일 이름 변경: 연희동 전통찻집다향_blog_content.csv -> yh_36547602_blog.csv
# 이디야커피 연희삼거리점
# 이디야커피 연희삼거리점에 해당하는 카페ID가 없습니다.
# 커피팝
# 파일 이름 변경: 연희동 커피팝_blog_content.csv -> yh_31397819_blog.csv
# CO끼리
# 파일 이름 변경: 연희동 CO끼리_blog_content.csv -> yh_1990953407_blog.csv
# 마켓까눌레
# 파일 이름 변경: 연희동 마켓까눌레_blog_content.csv -> yh_1128595707_blog.csv
# 더 미디엄
# 파일 이름 변경: 연희동 더 미디엄_blog_content.csv -> yh_19449292_blog.csv
# 파리바게뜨 연희대우점
# ...

# %% [markdown]
# #### 망원동

# %%
path = '../data/blog_review/blog_review_result_list/망원동'
# blog= pd.read_csv('../data/blog_review/blog_review_result_list/연남동.csv')
# 폴더 내 파일 리스트 가져오기
files = os.listdir(path)
len(files)

cafeId= pd.read_csv('../data/output_cafelist/cafe_info_list_mangone.csv')
len(cafeId)

import re
for file in files[10:]:
    try:
        result = re.search(r'망원동 (.*?)_', file)
        
        if result:
            cafeName = result.group(1)
            print(cafeName)
            
            # cafeId에서 '카페이름'이 cafeName을 포함하는 행 찾기
            matching_rows = cafeId[cafeId['카페이름'].str.contains(cafeName)]
            
            if not matching_rows.empty:
                id = int(matching_rows.iloc[0]['카페ID'])
                new_name = "mw_" + str(id) + "_blog.csv"
                
                old_path = os.path.join(path, file)
                new_path = os.path.join(path, new_name)
                
                os.rename(old_path, new_path)
                print(f"파일 이름 변경: {file} -> {new_name}")
            else:
                print(f"{cafeName}에 해당하는 카페ID가 없습니다.")
                old_path = os.path.join(path, file)
                os.remove(old_path)
                
        else:
            print(f"정규표현식 매칭 실패: {file}")
    except Exception as e:
        print(f"에러 발생: {e}")
# Out:
# 정규표현식 매칭 실패: mw_1711314210_blog.csv
# 정규표현식 매칭 실패: mw_38549516_blog.csv
# 정규표현식 매칭 실패: mw_1219761996_blog.csv
# 정규표현식 매칭 실패: mw_1210847446_blog.csv
# 정규표현식 매칭 실패: mw_1135306698_blog.csv
# 정규표현식 매칭 실패: mw_1878938830_blog.csv
# 정규표현식 매칭 실패: mw_1675098813_blog.csv
# 정규표현식 매칭 실패: mw_1405907736_blog.csv
# 정규표현식 매칭 실패: mw_1760548415_blog.csv
# 정규표현식 매칭 실패: mw_37654332_blog.csv
# 정규표현식 매칭 실패: mw_1727492792_blog.csv
# 정규표현식 매칭 실패: mw_1213764678_blog.csv
# 정규표현식 매칭 실패: mw_1576099617_blog.csv
# 정규표현식 매칭 실패: mw_1256673550_blog.csv
# 정규표현식 매칭 실패: mw_1725528988_blog.csv
# 정규표현식 매칭 실패: mw_1570284075_blog.csv
# 정규표현식 매칭 실패: mw_1051164520_blog.csv
# 정규표현식 매칭 실패: mw_1234832125_blog.csv
# 정규표현식 매칭 실패: mw_1403307689_blog.csv
# 정규표현식 매칭 실패: mw_1089102577_blog.csv
# 정규표현식 매칭 실패: mw_1988455172_blog.csv
# 정규표현식 매칭 실패: mw_1469082415_blog.csv
# 정규표현식 매칭 실패: mw_1030075333_blog.csv
# 정규표현식 매칭 실패: mw_1985146311_blog.csv
# 정규표현식 매칭 실패: mw_1258654458_blog.csv
# 정규표현식 매칭 실패: mw_1512650391_blog.csv
# ...

# %% [markdown]
# #### 한남동

# %%
path = '../data/blog_review/blog_review_result_list/한남동'
# blog= pd.read_csv('../data/blog_review/blog_review_result_list/연남동.csv')
# 폴더 내 파일 리스트 가져오기
files = os.listdir(path)
len(files)

cafeId= pd.read_csv('../data/output_cafelist/cafe_info_list_hannam.csv')
len(cafeId)

import re
for file in files[10:]:
    try:
        result = re.search(r'한남동 (.*?)_', file)
        
        if result:
            cafeName = result.group(1)
            print(cafeName)
            
            # cafeId에서 '카페이름'이 cafeName을 포함하는 행 찾기
            matching_rows = cafeId[cafeId['카페이름'].str.contains(cafeName)]
            
            if not matching_rows.empty:
                id = int(matching_rows.iloc[0]['카페ID'])
                new_name = "hn_" + str(id) + "_blog.csv"
                
                old_path = os.path.join(path, file)
                new_path = os.path.join(path, new_name)
                
                os.rename(old_path, new_path)
                print(f"파일 이름 변경: {file} -> {new_name}")
            else:
                print(f"{cafeName}에 해당하는 카페ID가 없습니다.")
                old_path = os.path.join(path, file)
                os.remove(old_path)
                
        else:
            print(f"정규표현식 매칭 실패: {file}")
    except Exception as e:
        print(f"에러 발생: {e}")
# Out:
# 정규표현식 매칭 실패: hn_1129772162_blog.csv
# 정규표현식 매칭 실패: hn_1238423329_blog.csv
# 정규표현식 매칭 실패: hn_1542287249_blog.csv
# 정규표현식 매칭 실패: hn_1416109994_blog.csv
# 정규표현식 매칭 실패: hn_1491093504_blog.csv
# 정규표현식 매칭 실패: hn_1503564190_blog.csv
# 정규표현식 매칭 실패: hn_1654360173_blog.csv
# 정규표현식 매칭 실패: hn_689929472_blog.csv
# 정규표현식 매칭 실패: hn_1041846907_blog.csv
# 정규표현식 매칭 실패: hn_1845157455_blog.csv
# 정규표현식 매칭 실패: hn_1126310741_blog.csv
# 정규표현식 매칭 실패: hn_1100009233_blog.csv
# 정규표현식 매칭 실패: hn_1211042040_blog.csv
# 정규표현식 매칭 실패: hn_1226510600_blog.csv
# 정규표현식 매칭 실패: hn_733920762_blog.csv
# 정규표현식 매칭 실패: hn_37196490_blog.csv
# 정규표현식 매칭 실패: hn_1728514968_blog.csv
# 정규표현식 매칭 실패: hn_1452914440_blog.csv
# 정규표현식 매칭 실패: hn_1007939018_blog.csv
# 정규표현식 매칭 실패: hn_13389647_blog.csv
# 정규표현식 매칭 실패: hn_1959653413_blog.csv
# 정규표현식 매칭 실패: hn_37793452_blog.csv
# 정규표현식 매칭 실패: hn_1802962451_blog.csv
# 정규표현식 매칭 실패: hn_1906908331_blog.csv
# 정규표현식 매칭 실패: hn_996334906_blog.csv
# 정규표현식 매칭 실패: hn_12851539_blog.csv
# ...
